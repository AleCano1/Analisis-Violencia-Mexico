# %%
# Add the Pandas dependency.
import pandas as pd
import numpy as np

# %%
violencia_2020= "Resources/2020_datos_violencia_delictiva.csv"

violencia_2020_df= pd.read_csv(violencia_2020)
violencia_2020_df.head()
# Out:
#     Año         Entidad Tipo de delito  Subtipo de delito          Modalidad  \
# 0  2020  Aguascalientes      Homicidio   Homicidio doloso  Con arma de fuego
# 1  2020  Aguascalientes      Homicidio   Homicidio doloso    Con arma blanca
# 2  2020  Aguascalientes      Homicidio   Homicidio doloso  Con otro elemento
# 3  2020  Aguascalientes      Homicidio   Homicidio doloso    No especificado
# 4  2020  Aguascalientes      Homicidio  Homicidio culposo  Con arma de fuego
#
#    Enero  Febrero  Marzo  Abril  Mayo  Junio  Julio  Agosto  Septiembre  \
# 0      2        6      3      3     2      3      5       2           1
# 1      0        1      2      0     2      0      1       1           0
# 2      1        1      1      0     2      2      1       2           0
# 3      0        0      0      0     0      0      0       0           0
# 4      0        0      0      0     0      0      0       0           0
#
#    Octubre  Noviembre  Diciembre
# 0        1          1          1
# ...

# %%
violencia_2019= "Resources/2019_datos_violencia_delictiva.csv"

violencia_2019_df= pd.read_csv(violencia_2019)
violencia_2019_df.head()
# Out:
#     Año  Clave_Ent         Entidad  Cve. Municipio       Municipio  \
# 0  2019          1  Aguascalientes            1001  Aguascalientes
# 1  2019          1  Aguascalientes            1001  Aguascalientes
# 2  2019          1  Aguascalientes            1001  Aguascalientes
# 3  2019          1  Aguascalientes            1001  Aguascalientes
# 4  2019          1  Aguascalientes            1001  Aguascalientes
#
#              Bien jurídico afectado Tipo de delito  Subtipo de delito  \
# 0  La vida y la Integridad corporal      Homicidio   Homicidio doloso
# 1  La vida y la Integridad corporal      Homicidio   Homicidio doloso
# 2  La vida y la Integridad corporal      Homicidio   Homicidio doloso
# 3  La vida y la Integridad corporal      Homicidio   Homicidio doloso
# 4  La vida y la Integridad corporal      Homicidio  Homicidio culposo
#
#            Modalidad  Enero  ...  Marzo  Abril  Mayo  Junio  Julio  Agosto  \
# ...

# %%
violencia_2019_df=violencia_2019_df.drop(['Clave_Ent','Cve. Municipio', 'Municipio','Cve. Municipio'], axis=1)
violencia_2019_df.head()
# Out:
#     Año         Entidad            Bien jurídico afectado Tipo de delito  \
# 0  2019  Aguascalientes  La vida y la Integridad corporal      Homicidio
# 1  2019  Aguascalientes  La vida y la Integridad corporal      Homicidio
# 2  2019  Aguascalientes  La vida y la Integridad corporal      Homicidio
# 3  2019  Aguascalientes  La vida y la Integridad corporal      Homicidio
# 4  2019  Aguascalientes  La vida y la Integridad corporal      Homicidio
#
#    Subtipo de delito          Modalidad  Enero  Febrero  Marzo  Abril  Mayo  \
# 0   Homicidio doloso  Con arma de fuego      5        4      2      2     2
# 1   Homicidio doloso    Con arma blanca      1        1      0      2     2
# 2   Homicidio doloso  Con otro elemento      1        2      2      2     1
# 3   Homicidio doloso    No especificado      0        0      0      0     2
# 4  Homicidio culposo  Con arma de fuego      0        0      0      0     0
#
#    Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre
# ...

# %%
violencia_2020_df.isnull().sum(axis=1)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 242153    0
# 242154    0
# 242155    0
# 242156    0
# 242157    0
# Length: 242158, dtype: int64

# %%
violencia_2020_df.tail()
# Out:
#          Año    Entidad                             Tipo de delito  \
# 242153  2020  Zacatecas                              Falsificación
# 242154  2020  Zacatecas                   Contra el medio ambiente
# 242155  2020  Zacatecas  Delitos cometidos por servidores públicos
# 242156  2020  Zacatecas                                Electorales
# 242157  2020  Zacatecas              Otros delitos del Fuero Común
#
#                                 Subtipo de delito  \
# 242153                              Falsificación
# 242154                   Contra el medio ambiente
# 242155  Delitos cometidos por servidores públicos
# 242156                                Electorales
# 242157              Otros delitos del Fuero Común
#
#                                         Modalidad  Enero  Febrero  Marzo  \
# 242153                              Falsificación      0        0      0
# 242154                   Contra el medio ambiente      0        0      0
# ...

# %%
violencia_2019_df.tail()
# Out:
#          Año    Entidad                             Bien jurídico afectado  \
# 242153  2019  Zacatecas  Otros bienes jurídicos afectados (del fuero co...
# 242154  2019  Zacatecas  Otros bienes jurídicos afectados (del fuero co...
# 242155  2019  Zacatecas  Otros bienes jurídicos afectados (del fuero co...
# 242156  2019  Zacatecas  Otros bienes jurídicos afectados (del fuero co...
# 242157  2019  Zacatecas  Otros bienes jurídicos afectados (del fuero co...
#
#                                    Tipo de delito  \
# 242153                              Falsificación
# 242154                   Contra el medio ambiente
# 242155  Delitos cometidos por servidores públicos
# 242156                                Electorales
# 242157              Otros delitos del Fuero Común
#
#                                 Subtipo de delito  \
# 242153                              Falsificación
# 242154                   Contra el medio ambiente
# 242155  Delitos cometidos por servidores públicos
# ...

# %%
violencia_2019_df["Modalidad"].value_counts()
# Out:
# Con violencia                                                                          29652
# Sin violencia                                                                          29652
# Con arma de fuego                                                                      12355
# Con otro elemento                                                                      12355
# No especificado                                                                        12355
# Con arma blanca                                                                        12355
# En accidente de tránsito                                                                4942
# Despojo                                                                                 2471
# Violencia familiar                                                                      2471
# Otros delitos contra el patrimonio                                                      2471
# ...

# %%
violencia_2019_df["Enero"].sum()
# Out:
# 162940

# %%
violencia_2019_df["Total"]=violencia_2019_df.sum(axis=1, columns= "Enero", "Febrero")
# Out:
#   File "C:\Users\ALEJAN~1\AppData\Local\Temp/ipykernel_15840/3635066880.py", line 1
#     violencia_2019_df["Total"]=violencia_2019_df.sum(axis=1, columns= "Enero", "Febrero")
#                                                                               ^
# SyntaxError: positional argument follows keyword argument

# %%
violencia_2019_df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ALEJAN~1\AppData\Local\Temp/ipykernel_15840/3754507726.py in <module>
# ----> 1 violencia_2019_df.type()
#
# ~\anaconda3\envs\PythonData\envs\PythonData\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
def add_numbers(a, b, c, d, e, f, g, h, i, j, k, l):
    return a+b+c+d+e+f+g+h+i+j+k+l

# %%
result=add_numbers(["Enero","Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre","Octubre","Noviembre","Diciembre"])
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ALEJAN~1\AppData\Local\Temp/ipykernel_15840/3660494750.py in <module>
# ----> 1 result=add_numbers(["Enero","Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre","Octubre","Noviembre","Diciembre"])
#       2 print(result)
#
# TypeError: add_numbers() missing 11 required positional arguments: 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', and 'l'
